# %% [markdown]
# # Movie Simple Recommendation

# %% [markdown]
# Analizing the database of The Movies Dataset: [The Movies Dataset](https://www.kaggle.com/rounakbanik/the-movies-dataset)
#
#
# inspired by [Movie Recommender Systems](https://www.kaggle.com/rounakbanik/movie-recommender-systems/notebook)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval

# %%
md = pd.read_csv('2-Data/movies_metadata.csv')
print(md.shape)
md[:5]
# Out:
# (44048, 22)
#    Unnamed: 0  adult    budget  \
# 0           0  False  30000000
# 1           1  False  65000000
# 2           2  False         0
# 3           3  False  16000000
# 4           4  False         0
#
#                                               genres     id    imdb_id  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862  tt0114709
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844  tt0113497
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602  tt0113228
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357  tt0114885
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
# ...

# %%
md['genres'][:5]
# Out:
# 0    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2    [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                       [{'id': 35, 'name': 'Comedy'}]
# Name: genres, dtype: object

# %%
md['genres'] = md['genres'].apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
md['genres'][:5]
# Out:
# 0     [Animation, Comedy, Family]
# 1    [Adventure, Fantasy, Family]
# 2               [Romance, Comedy]
# 3        [Comedy, Drama, Romance]
# 4                        [Comedy]
# Name: genres, dtype: object

# %% [markdown]
# ### Weighted Rating (WR) =  (v/(v+m)*R)+(m/(v+m)*C)
#
# v is the number of votes for the movie<br/>
# m is the minimum votes required to be listed in the chart<br/>
# R is the average rating of the movie<br/>
# C is the mean vote across the whole report<br/>

# %%
vote_counts = md[md['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = md[md['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
C
# Out:
# 5.294746640029059

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=md, x='vote_count')
plt.title('Boxplot of vote_count')
# Out:
# Text(0.5, 1.0, 'Boxplot of vote_count')

# %%
m = vote_counts.quantile(0.95)
m
# Out:
# 452.65000000000146

# %%
md['year'] = pd.to_datetime(md['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] 
                                                                       if x != np.nan else np.nan)

# %%
md[:2]
# Out:
#    Unnamed: 0  adult    budget                        genres    id    imdb_id  \
# 0           0  False  30000000   [Animation, Comedy, Family]   862  tt0114709
# 1           1  False  65000000  [Adventure, Fantasy, Family]  8844  tt0113497
#
#   original_language original_title  \
# 0                en      Toy Story
# 1                en        Jumanji
#
#                                             overview  popularity  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943  ...
# 1  When siblings Judy and Peter discover an encha...   17.015539  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status      title  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released  Toy Story
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released    Jumanji
#
#    video vote_average vote_count  year
# ...

# %%
qualified = md[(md['vote_count'] >= m) & (md['vote_count'].notnull()) & (md['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')
qualified.shape
# Out:
# (2203, 6)

# %%
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
qualified['wr'] = qualified.apply(weighted_rating, axis=1)

# %%
qualified = qualified.sort_values('wr', ascending=False)

# %% [markdown]
# ### Top Movies

# %%
qualified[:10]
# Out:
#                                                    title  year  vote_count  \
# 15362                                          Inception  2010       14075
# 12411                                    The Dark Knight  2008       12269
# 22550                                       Interstellar  2014       11187
# 2810                                          Fight Club  1999        9678
# 4821   The Lord of the Rings: The Fellowship of the Ring  2001        8892
# 290                                         Pulp Fiction  1994        8670
# 311                             The Shawshank Redemption  1994        8358
# 6946       The Lord of the Rings: The Return of the King  2003        8226
# 348                                         Forrest Gump  1994        8147
# 5769               The Lord of the Rings: The Two Towers  2002        7641
#
#        vote_average  popularity  \
# 15362             8   29.108149
# 12411             8  123.167259
# 22550             8   32.213481
# ...

# %% [markdown]
# #### Separating Movie Genres

# %%
s = md.apply(lambda x: pd.Series(x['genres'],dtype='string'),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'genre'
gen_md = md.drop('genres', axis=1).join(s)

# %%
gen_md[:3]
# Out:
#    Unnamed: 0  adult    budget   id    imdb_id original_language  \
# 0           0  False  30000000  862  tt0114709                en
# 0           0  False  30000000  862  tt0114709                en
# 0           0  False  30000000  862  tt0114709                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
#
#    popularity                       poster_path  ...      revenue runtime  \
# 0   21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...  373554033.0    81.0
# 0   21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...  373554033.0    81.0
# 0   21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...  373554033.0    81.0
#
#                            spoken_languages    status      title  video  \
# ...

# %%
def build_chart(genre, percentile=0.85):
    df = gen_md[gen_md['genre'] == genre]
    vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_averages.mean()
    m = vote_counts.quantile(percentile)
    
    qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity']]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    
    qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) + (m/(m+x['vote_count']) * C), axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(250)
    
    return qualified

# %% [markdown]
# ### Top Action Movies

# %%
build_chart('Action')[:10]
# Out:
#                                                    title  year  vote_count  \
# 15362                                          Inception  2010       14075
# 12411                                    The Dark Knight  2008       12269
# 4821   The Lord of the Rings: The Fellowship of the Ring  2001        8892
# 6946       The Lord of the Rings: The Return of the King  2003        8226
# 5769               The Lord of the Rings: The Two Towers  2002        7641
# 254                                            Star Wars  1977        6778
# 1135                             The Empire Strikes Back  1980        5998
# 4096                                            Scarface  1983        3017
# 9368                                              Oldboy  2003        2000
# 1880                                       Seven Samurai  1954         892
#
#        vote_average  popularity        wr
# 15362             8   29.108149  7.954488
# 12411             8  123.167259  7.947913
# ...

# %% [markdown]
# ### Top Action Movies

# %%
build_chart('Romance')[:10]
# Out:
#                              title  year  vote_count  vote_average  \
# 10243  Dilwale Dulhania Le Jayenge  1995         661             9
# 348                   Forrest Gump  1994        8147             8
# 859                        Vertigo  1958        1162             8
# 39155                   Your Name.  2016        1030             8
# 866               Some Like It Hot  1959         835             8
# 1113               Cinema Paradiso  1988         834             8
# 19672                     Paperman  2012         734             8
# 36856                  Sing Street  2016         669             8
# 865                  The Apartment  1960         498             8
# 37676               The Handmaiden  2016         453             8
#
#        popularity        wr
# 10243   34.457024  8.562194
# 348     48.307194  7.971153
# 859     18.208220  7.810472
# 39155   34.461252  7.788175
# 866     11.845107  7.743616
# 1113    14.177005  7.743339
# ...

# %% [markdown]
# ### Top Action Movies

# %%
build_chart('Animation')[:10]
# Out:
#                         title  year  vote_count  vote_average  popularity  \
# 356             The Lion King  1994        5520             8   21.605761
# 5439            Spirited Away  2001        3968             8   41.048867
# 9635     Howl's Moving Castle  2004        2049             8   16.136048
# 2851        Princess Mononoke  1997        2041             8   17.166725
# 5788       My Neighbor Totoro  1988        1730             8   13.507299
# 39155              Your Name.  2016        1030             8   34.461252
# 5511   Grave of the Fireflies  1988         974             8    0.010902
# 19672                Paperman  2012         734             8    7.198633
# 38326                   Piper  2016         487             8   11.243161
# 20516           Wolf Children  2012         483             8   10.249498
#
#              wr
# 356    7.909469
# 5439   7.876135
# 9635   7.772613
# 2851   7.771818
# 5788   7.735925
# 39155  7.591181
# 5511   7.572433
# ...
